# %% [markdown]
# ## PII (Personal Identifiable Information) - MultiLabel Classification

# %% [markdown]
# Tensorflow, LSTM, NLTK, RE, Sklearn

# %%
#Required libraries 
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from nltk.corpus import wordnet
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout

# %%
#Load the excel file pandas read the file using ExcelFile
xls = pd.ExcelFile('PII_Train_Large_Data_Test_Data.xlsx')
xls.sheet_names #See if the data is in one sheet or available in mutiple
# Out:
# ['Export Summary',
#  'PII Train Large Data - PII Trai',
#  'PII Test Data - PII Test Data']

# %% [markdown]
# 'PII Train Large Data - PII Trai' --AND-- 'PII Test Data - PII Test Data'

# %%
#Extarct the train_data from  'PII Train Large Data - PII Trai' sheet
train_data = pd.read_excel(xls, 'PII Train Large Data - PII Trai')
train_data.columns
# Out:
# Index(['PII Train Large Data', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
train_data.head()
# Out:
#                                 PII Train Large Data Unnamed: 1  \
# 0                                               Text     Labels
# 1  Candidate economic character present money dau...    Address
# 2        Film range sound. People age Apt. 476 that.    Address
# 3  Back want myself class certain. Tree pretty ca...    Address
# 4  Bring guy 81627 Kimberly Squares Washingtonber...    Address
#
#                                         Unnamed: 2
# 0                                              PII
# 1                                         Apt. 026
# 2                                         Apt. 476
# 3                                        Suite 492
# 4  81627 Kimberly Squares Washingtonberg, RI 13540

# %%
#Extarct the train_data from  'PII Train Large Data - PII Trai' sheet
test_data = pd.read_excel(xls, 'PII Test Data - PII Test Data')
test_data.columns
# Out:
# Index(['PII Test Data', 'Unnamed: 1', 'Unnamed: 2'], dtype='object')

# %%
test_data.head()
# Out:
#                                        PII Test Data Unnamed: 1 Unnamed: 2
# 0                                               Text      Label        PII
# 1  Term although process suddenly parent. Poor go...        NaN        NaN
# 2  356 Collins Highway New Kathleen, NM 10160 Rem...        NaN        NaN
# 3  Appear job opportunity job. Piece 405 Callahan...        NaN        NaN
# 4  During half leave simple west lose piece 859 D...        NaN        NaN

# %% [markdown]
# ### Data Cleaning

# %%
#set the dataframe 
train_data = pd.read_excel(xls, 'PII Train Large Data - PII Trai', skiprows = 1)
train_data.columns
# Out:
# Index(['Text', 'Labels', 'PII'], dtype='object')

# %%
train_data.sample(10)
# Out:
#                                                   Text            Labels  \
# 658  Nature American should reduce two. Store goal ...               SSN
# 194  Store effort campaign girl worker technology. ...  CreditCardNumber
# 708  Cup item remain environment not. Foot nation k...              None
# 73   Again 970 Bethany Fords Suite 491 West Lisasid...           Address
# 600  Candidate economic character present 829 49 91...               SSN
# 334  Room up generation free discover grow. Pattern...              Name
# 94   Store effort campaign girl worker technology. ...           Address
# 448  Party woman past grow edge. Pretty eat Democra...      Phone_number
# 385         White Ready off score foot market protect.              Name
# 82   Course college still loss Apt. 745 scene. Seri...           Address
#
#                                                    PII
# 658                                        693 88 4776
# 194                                       676293890015
# 708                                               None
# 73   970 Bethany Fords Suite 491 West Lisaside, NC ...
# 600                                        829 49 9139
# 334                                        Mary Miller
# 94   309 Bryan Islands Suite 301 Lake Valerie, CO 9...
# 448                                       800-428-6217
# 385                                              White
# 82                                            Apt. 745

# %%
#set the dataframe 
test_data = pd.read_excel(xls, 'PII Test Data - PII Test Data', skiprows = 1)
test_data.columns
# Out:
# Index(['Text', 'Label', 'PII'], dtype='object')

# %%
test_data.sample(5)
# Out:
#                                                     Text  Label  PII
# 8429   Southern measure cultural teacher. (490)446-52...    NaN  NaN
# 10182  Recent air government simply it yourself. Sist...    NaN  NaN
# 4847   Specific owner wburns@gmail.com reveal travel....    NaN  NaN
# 1260   Minute floor mean 90696 Mckenzie Corners Apt. ...    NaN  NaN
# 4972   Certainly free natural both. Receive approach ...    NaN  NaN

# %%
#keep a copy of original text and add one more lower_text column
train_data['lower_text']= train_data['Text'].str.lower()
train_data.sample(10)
# Out:
#                                                   Text   Labels  \
# 395  Coach he west magazine against beat. By someti...     Name
# 250  Old to health ask martinmichelle@wilkinson.com...    Email
# 354  Civil notice travel commercial. Consumer itsel...     Name
# 752  Exist establish we reason job record accept. W...     None
# 298  Test artist person billion. sherri68@gmail.com...    Email
# 63   52013 Jason Vista Lake Kathleen, PA 89168 Fede...  Address
# 342  Goal agent resource office material game. Lot ...     Name
# 228  Everyone road skill act condition heart frobin...    Email
# 737  Ok dream campaign task six only Congress. Scor...     None
# 76   Any information garden to citizen movie hear a...  Address
#
#                                            PII  \
# 395                             Christina Hill
# 250               martinmichelle@wilkinson.com
# 354                               Joseph Lewis
# 752                                       None
# 298                         sherri68@gmail.com
# 63   52013 Jason Vista Lake Kathleen, PA 89168
# 342                                     Nelson
# 228                      frobinson@romero.info
# 737                                       None
# 76      92546 Clark Vista Stephenton, IL 39677
#
#                                             lower_text
# 395  coach he west magazine against beat. by someti...
# 250  old to health ask martinmichelle@wilkinson.com...
# 354  civil notice travel commercial. consumer itsel...
# 752  exist establish we reason job record accept. w...
# 298  test artist person billion. sherri68@gmail.com...
# 63   52013 jason vista lake kathleen, pa 89168 fede...
# 342  goal agent resource office material game. lot ...
# 228  everyone road skill act condition heart frobin...
# 737  ok dream campaign task six only congress. scor...
# 76   any information garden to citizen movie hear a...

# %%
test_data['lower_text']= test_data['Text'].str.lower()
test_data.sample(5)
# Out:
#                                                     Text  Label  PII  \
# 7656   Prepare financial your wear watch manage. Ande...    NaN  NaN
# 8259   001-341-907-5046x17440 High future east receiv...    NaN  NaN
# 10416  Do relate single board. Along lose former chan...    NaN  NaN
# 6966   Drug operation bag employee south increase acc...    NaN  NaN
# 14161  Weight western raise science might. Reduce yea...    NaN  NaN
#
#                                               lower_text
# 7656   prepare financial your wear watch manage. ande...
# 8259   001-341-907-5046x17440 high future east receiv...
# 10416  do relate single board. along lose former chan...
# 6966   drug operation bag employee south increase acc...
# 14161  weight western raise science might. reduce yea...

# %%
#clean any double spaces if present in the text
def rmExtraSpace(text):
    r = re.sub("\s+", " " , text)
    return r

train_data.lower_text.apply(lambda x: rmExtraSpace(x))
train_data['lower_text'].sample(5)
# Out:
# 452    exist establish we reason job record accept. w...
# 469    character film 001-753-147-3410 whole above op...
# 714    wear language word kitchen might figure miss j...
# 710    sound improve parent dream send language. hund...
# 228    everyone road skill act condition heart frobin...
# Name: lower_text, dtype: object

# %%
test_data.lower_text.apply(lambda x: rmExtraSpace(x))
test_data['lower_text'].sample(5)
# Out:
# 2752     magazine common town apply. relate model there...
# 4653     road candidate behavior important girl develop...
# 9040     indeed sometimes analysis place get federal na...
# 7247               film cold especially john likely media.
# 10560    reach although nice analysis amount opportunit...
# Name: lower_text, dtype: object

# %% [markdown]
# ### Pre-process the data

# %%
#Since we observe different number formats in the text
#Processing the text to fit into the model later

# %%
#Identify the Numbers and replace with the len(number)D
def identifyNumbers(text):
    index = 0
    while index < (len(text)):
        ch = text[index]
        if ch.isdigit():
            count = count_digits(text, index)
            # Replace the text
            replacementstring= '{}D'.format(count)
            replacementstring_length = len(replacementstring)
            text = text[:index]+replacementstring+text[index+count:]
            index = index + replacementstring_length
        else:
            index +=1
    return text


def count_digits(text, index):
    count = 0
    while index<len(text) and text[index].isdigit():
        count +=1
        index +=1
    return count

# %%
#Imply the count_digits and replace 
train_data['lower_text'] = train_data.lower_text.apply(lambda x: identifyNumbers(x))
train_data['lower_text'].sample(5)
# Out:
# 49     series seem sister health. identify company au...
# 562    around well meet whose five 3D 1Ddi before. so...
# 614    wear language word kitchen might figure miss j...
# 685        ready off score foot market protect. 3D 2D 4D
# 698    test artist person billion. trouble staff indu...
# Name: lower_text, dtype: object

# %%
#Imply the count_digits and replace 
test_data['lower_text'] = test_data.lower_text.apply(lambda x: identifyNumbers(x))
test_data['lower_text'].sample()
# Out:
# 14986    modern appear everyone. culture reality wife a...
# Name: lower_text, dtype: object

# %%
test_data['lower_text'].sample(5)
# Out:
# 13673    democrat plan pretty everybody. forget 3D-2D-4...
# 2438     car child while space community human 16D your...
# 192      whatever technology rather artist early throug...
# 8559     force financial and. tonight discover ago fear...
# 2973     relationship according heart what. film daught...
# Name: lower_text, dtype: object

# %%
#Adding space when len(numbers) to make it easy way to tokenize the data.

def addSpaceBeforeAfterDigit(text):
    index = 0
    while index < len(text):
        ch = text[index]
        if ch != ' ' and not ch.isalnum():
            if index >=2:
                if text[index-2].isdigit():
                    text = text[:index] + ' ' + text[index:]
                    index +=1
            if index < len(text) - 1:
                if text[index+1].isdigit():
                    text = text[:index+1] + ' ' + text[index+1:]
                    index +=1
        index+=1
        
    return text


train_data['lower_text'] = train_data.lower_text.apply(lambda x: addSpaceBeforeAfterDigit(x))
train_data.sample(5)
# Out:
#                                                   Text            Labels  \
# 376  Any information garden to citizen movie hear a...              Name
# 795  Coach he west magazine against beat. By someti...              None
# 158  Nature American should reduce two. Store goal ...  CreditCardNumber
# 259  Defense region trade hold bed time audience ch...             Email
# 289  Describe question cover suggest actually with....             Email
#
#                          PII  \
# 376                    Henry
# 795                     None
# 158           30483588661316
# 259       lowens@hotmail.com
# 289  johnsontracey@gmail.com
#
#                                             lower_text
# 376  any information garden to citizen movie hear a...
# 795  coach he west magazine against beat. by someti...
# 158  nature american should reduce two. store goal ...
# 259  defense region trade hold bed time audience ch...
# 289  describe question cover suggest actually with....

# %%
test_data['lower_text'] = test_data.lower_text.apply(lambda x: addSpaceBeforeAfterDigit(x))
test_data.sample(5)
# Out:
#                                                    Text  Label  PII  \
# 8652  Say especially large interview. 876.088.2835 H...    NaN  NaN
# 7083  Return truth hand either Tyler leader to outsi...    NaN  NaN
# 4908  Form pull describe resource character full ste...    NaN  NaN
# 4552  Table collection shake church cover pay stuff....    NaN  NaN
# 6496  Your foreign answer thus turn. Person fall man...    NaN  NaN
#
#                                              lower_text
# 8652  say especially large interview. 3D . 3D . 4D h...
# 7083  return truth hand either tyler leader to outsi...
# 4908  form pull describe resource character full ste...
# 4552  table collection shake church cover pay stuff....
# 6496  your foreign answer thus turn. person fall man...

# %%
def wTokenize(words):
    filtered_sentence = []
    words = word_tokenize(words)
    for w in words:
        if w not in stop:
            filtered_sentence.append(w)
    return filtered_sentence

train_data['lower_text'] = train_data['lower_text'].apply(lambda x: wTokenize(x))

# %%
train_data['lower_text'].sample(5)
# Out:
# 283    [movement, near, heathergibson, @, miller.com,...
# 363    [federal, nice, idea, sell, ., somebody, edwin...
# 492    [report, author, increase, 3D, -, 3D, -, 4Dx4D...
# 778    [break, light, base, sea, ., magazine, decide,...
# 756    [program, indicate, whose, attorney, five, acc...
# Name: lower_text, dtype: object

# %% [markdown]
# ### Build model

# %%
#The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 5000
#Max number of words in each text.
MAX_SEQUENCE_LENGTH = 250
#Embedding can be set fixed.
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-/:;<=>?[\]^_`{|}~', lower=True)
#tokenizer = Tokenizer(nb_words=MAX_NB_WORDS)
X = tokenizer.fit_on_texts(train_data['lower_text'].values)
X = sequences = tokenizer.texts_to_sequences(train_data['lower_text'].values)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

X = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

print('Shape of data tensor:', X.shape)
# Out:
# Found 1058 unique tokens.
# Shape of data tensor: (800, 250)

# %% [markdown]
# Used same parameter for test_data

# %%
Y = pd.get_dummies(train_data['Labels']).values
print('Shape of label tensor:', Y.shape)
# Out:
# Shape of label tensor: (800, 8)

# %%
#Split Train Test 
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (640, 250) (640, 8)
# (160, 250) (160, 8)

# %%
# #Embedding can be set fixed.
# EMBEDDING_DIM = 100

model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, # size of the embedded vectors
                    input_length=MAX_SEQUENCE_LENGTH))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))# returns a sequence of vectors of dimension 10
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy',#loss
              optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 250, 100)          500000
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 250, 100)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 8)                 808
# =================================================================
# Total params: 581,208
# Trainable params: 581,208
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_train.shape,Y_train.shape
# Out:
# ((640, 250), (640, 8))

# %%
#Model fit
epochs = 5
batch_size = 8

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,
                    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/5
# 80/80 [==============================] - 26s 293ms/step - loss: 2.0716 - accuracy: 0.1538
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/5
# 80/80 [==============================] - 22s 276ms/step - loss: 1.7819 - accuracy: 0.2395
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/5
# 80/80 [==============================] - 21s 264ms/step - loss: 1.3691 - accuracy: 0.4234
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/5
# 80/80 [==============================] - 21s 255ms/step - loss: 1.0131 - accuracy: 0.6261
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/5
# 80/80 [==============================] - 21s 260ms/step - loss: 0.6985 - accuracy: 0.7121
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy

# %%
accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 5/5 [==============================] - 1s 68ms/step - loss: 1.0345 - accuracy: 0.5500
# Test set
#   Loss: 1.034
#   Accuracy: 0.550

# %%
new_text = ['my number is sreess@123.com']
seq = tokenizer.texts_to_sequences(new_text)
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = model.predict(padded)
labels = ['SSN', 'Name', 'Address', 'CreditCardNumber', 'Email', 'Phone_number', 'Plates', 'None']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.05052647 0.2055744  0.0435201  0.20960784 0.22173166 0.04189555
#   0.17518768 0.0519564 ]] Email

# %%
new_text = ['my number is (123) 45 5478']
seq = tokenizer.texts_to_sequences(new_text)
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = model.predict(padded)
labels = ['SSN', 'Name', 'Address', 'CreditCardNumber', 'Email', 'Phone_number', 'Plates', 'None']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.05052647 0.2055744  0.0435201  0.20960784 0.22173166 0.04189555
#   0.17518768 0.0519564 ]] SSN

# %%
new_text = ['ned wants the ghe and says he is in 7787 brown st apt. 123']
seq = tokenizer.texts_to_sequences(new_text)
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = model.predict(padded)
labels = ['SSN', 'Name', 'Address', 'CreditCardNumber', 'Email', 'Phone_number', 'Plates', 'None']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.06509028 0.18201326 0.05197835 0.19698647 0.20959812 0.05382587
#   0.17648517 0.0640225 ]] Address

# %%
new_text = ['ma indication to the nullable info in the street of nba is 12556344447777599']
seq = tokenizer.texts_to_sequences(new_text)
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = model.predict(padded)
labels = ['SSN', 'Name', 'Address', 'CreditCardNumber', 'Email', 'Phone_number', 'Plates', 'None']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.06509028 0.18201326 0.05197835 0.19698647 0.20959812 0.05382587
#   0.17648517 0.0640225 ]] CreditCardNumber

# %% [markdown]
# ## Regular expresion functionality in PII and  human name parser (NLTK)

# %%
#Load the excel file pandas read the file using ExcelFile
xls = pd.ExcelFile('PII_Train_Large_Data_Test_Data.xlsx')
xls.sheet_names #See if the data is in one sheet or available in mutiple
# Out:
# ['Export Summary',
#  'PII Train Large Data - PII Trai',
#  'PII Test Data - PII Test Data']

# %%
#set the dataframe 
train_data = pd.read_excel(xls, 'PII Train Large Data - PII Trai', skiprows = 1)
train_data.columns
# Out:
# Index(['Text', 'Labels', 'PII'], dtype='object')

# %%
train_data.sample(10)
# Out:
#                                                   Text            Labels  \
# 110  Sound improve parent dream send language. Hund...  CreditCardNumber
# 710  Sound improve parent dream send language. Hund...              None
# 330                Most nor star Monica Abbott remain.              Name
# 571  Road audience large this. Future artist condit...            Plates
# 796  Speech national especially available own black...              None
# 561  Certainly success training N56 4LY idea large....            Plates
# 318  Community stand nice whatever film. Blood go p...              Name
# 589  Describe 8-89413E question cover suggest actua...            Plates
# 349  Series seem Jeff Mason sister health. Identify...              Name
# 270  zyoung@drake.org Drop yet bad each whose. Mach...             Email
#
#                   PII
# 110  2254280030993205
# 710              None
# 330     Monica Abbott
# 571           815 5DI
# 796              None
# 561           N56 4LY
# 318            Nelson
# 589          8-89413E
# 349        Jeff Mason
# 270  zyoung@drake.org

# %%
import re
def address(text):
    regexp = "[0-9]{1,5}.+, [A-Z]{2} [0-9]{1,5}"
    a = re.findall(regexp, text)
    if len(a) != 0:
        return a
    d=re.findall("[0-9]{1,5} [A-Z][A-Za-z]+ [[A-Z][A-Za-z]+]? [A[PT|pt]\.? ?[0-9]{1,4}]?",text)
    if len(d) !=0:
        return d
    b=re.findall("Apt. +[0-9]{1,4}",text)
    if len(b) != 0:
        return b
    c=re.findall("Suite +[0-9]{1,4}",text)
    if len(c) !=0:
        return c
    

train_data['Digit_data'] = train_data.Text.apply(lambda x: address(x))
train_data.head(150)
# Out:
#                                                   Text            Labels  \
# 0    Candidate economic character present money dau...           Address
# 1          Film range sound. People age Apt. 476 that.           Address
# 2    Back want myself class certain. Tree pretty ca...           Address
# 3    Bring guy 81627 Kimberly Squares Washingtonber...           Address
# 4    52013 Jason Vista Lake Kathleen, PA 89168 May ...           Address
# 5    Themselves early our bit. Institution peace sp...           Address
# 6    11792 Stevens Ferry Career respond front happe...           Address
# 7    Fine during five spring Apt. 174 page where la...           Address
# 8    Cup 52013 Jason Vista Lake Kathleen, PA 89168 ...           Address
# 9    Question Suite 052 as should sign face. Memory...           Address
# 10   Sound improve parent dream 57439 Barron Shoals...           Address
# 11   We 57439 Barron Shoals Apt. 718 trial win. Ind...           Address
# 12   Series painting development simply good. Hour ...           Address
# 13   Gun Suite 281 billion skin. Find success force...           Address
# 14   Wear language Apt. 476 word kitchen might figu...           Address
# 15   Organization rich Suite 751 indicate medical e...           Address
# 16   Job security fall 32266 Patterson Plain Suite ...           Address
# 17   Lay case final. East dark week account structu...           Address
# 18   Community stand nice whatever film. Blood go p...           Address
# 19   View consumer our. Kind simple support. Operat...           Address
# 20   Soon study though Apt. 406 once. Former grow a...           Address
# 21   Although foreign national clearly church estab...           Address
# 22   Mission throughout small USNS Wilson FPO AE 70...           Address
# 23   Member evening ready. Choose 60467 Deborah Vis...           Address
# 24   Support do total threat exist material. Here b...           Address
# 25   Close pressure finally. Young question Mrs 156...           Address
# 26   Quality whom pay travel our table course. 970 ...           Address
# 27   Relationship what family state time artist sid...           Address
# 28   Everyone road skill Apt. 392 act condition hea...           Address
# 29   Fight strategy maintain every Suite 298 becaus...           Address
# ..                                                 ...               ...
# 120  Soon study though once. Former grow around 180...  CreditCardNumber
# 121  Although foreign national clearly church estab...  CreditCardNumber
# 122  Mission throughout 180001995283371 small save ...  CreditCardNumber
# 123  Member evening ready. Choose quality 356333014...  CreditCardNumber
# 124  Support do total threat exist material. Here b...  CreditCardNumber
# 125  Close pressure finally. Young question 4800729...  CreditCardNumber
# 126  Quality whom pay travel our 4914569109182 tabl...  CreditCardNumber
# 127  Relationship what family state time artist sid...  CreditCardNumber
# 128  Everyone road skill act condition heart 384943...  CreditCardNumber
# 129  Fight strategy maintain every 6563716230495464...  CreditCardNumber
# 130                 Most nor 584516367052 star remain.  CreditCardNumber
# 131  Team Republican him reveal. Player party 42820...  CreditCardNumber
# 132  One than light class. Between impact those 305...  CreditCardNumber
# 133  During technology weight appear gun. Soon clai...  CreditCardNumber
# 134  Room up generation free discover grow. Pattern...  CreditCardNumber
# 135  Never break about risk. Pay number west econom...  CreditCardNumber
# 136  Strong whole head name mean. American lose 180...  CreditCardNumber
# 137  Ok dream campaign task six only 45626907121042...  CreditCardNumber
# 138  Town minute 676115522119 culture throughout bu...  CreditCardNumber
# 139  Radio respond perhaps western loss blood. Turn...  CreditCardNumber
# 140  Approach article scene though respond white so...  CreditCardNumber
# 141  Cell town administration arm. 4616277450788213...  CreditCardNumber
# 142  Goal agent resource 4993313326896 office mater...  CreditCardNumber
# 143  History effort system kitchen. Heart your 6558...  CreditCardNumber
# 144  4799645906604147647 Leader any type improve fi...  CreditCardNumber
# 145  Thank 4799645906604147647 realize edge quality...  CreditCardNumber
# 146  Discover author 6558145461622090 see president...  CreditCardNumber
# 147  Easy have whatever point 3584995274800308 bett...  CreditCardNumber
# 148  Party woman past grow edge. Pretty eat Democra...  CreditCardNumber
# 149  Series seem sister health. Identify 4684949676...  CreditCardNumber
#
#                                                    PII  \
# 0                                             Apt. 026
# 1                                             Apt. 476
# 2                                            Suite 492
# 3      81627 Kimberly Squares Washingtonberg, RI 13540
# 4            52013 Jason Vista Lake Kathleen, PA 89168
# 5       4058 Gordon Fields South Charlestown, NJ 40537
# 6                                  11792 Stevens Ferry
# 7                                             Apt. 174
# 8            52013 Jason Vista Lake Kathleen, PA 89168
# 9                                            Suite 052
# 10                        57439 Barron Shoals Apt. 718
# 11                        57439 Barron Shoals Apt. 718
# 12                              USNS Pugh FPO AA 12405
# 13                                           Suite 281
# 14                                            Apt. 476
# 15                                           Suite 751
# 16   32266 Patterson Plain Suite 265 Alexandrashire...
# 17                                           Suite 056
# 18       71707 Leblanc River New Annaborough, ID 83252
# 19                        73727 Rebecca Spur Suite 674
# 20                                            Apt. 406
# 21                                     049 Andrea Loaf
# 22                            USNS Wilson FPO AE 70648
# 23   60467 Deborah Vista Apt. 146 Port Karenfurt, V...
# 24   970 Bethany Fords Suite 491 West Lisaside, NC ...
# 25                                    156 John Gardens
# 26   970 Bethany Fords Suite 491 West Lisaside, NC ...
# 27                                            Apt. 798
# 28                                            Apt. 392
# 29                                           Suite 298
# ..                                                 ...
# 120                                    180094837534853
# 121                                   3571057486367876
# 122                                    180001995283371
# 123                                   3563330148426475
# 124                                   4534678333333995
# 125                                   4800729495489583
# 126                                      4914569109182
# 127                                   3509479106877737
# 128                                     38494361631717
# 129                                   6563716230495464
# 130                                       584516367052
# 131                                   4282096422839141
# 132                                     30579838131834
# 133                                   2539669222044446
# 134                                      4914569109182
# 135                                   3536439571940276
# 136                                    180094837534853
# 137                                   4562690712104207
# 138                                       676115522119
# 139                                      4824730605358
# 140                                   6563716230495464
# 141                                   4616277450788213
# 142                                      4993313326896
# 143                                   6558145461622090
# 144                                4799645906604147647
# 145                                4799645906604147647
# 146                                   6558145461622090
# 147                                   3584995274800308
# 148                                       630466700238
# 149                                   4684949676197398
#
#                                             Digit_data
# 0                                           [Apt. 026]
# 1                                           [Apt. 476]
# 2                                          [Suite 492]
# 3    [81627 Kimberly Squares Washingtonberg, RI 13540]
# 4          [52013 Jason Vista Lake Kathleen, PA 89168]
# 5     [4058 Gordon Fields South Charlestown, NJ 40537]
# 6                                                 None
# 7                                           [Apt. 174]
# 8          [52013 Jason Vista Lake Kathleen, PA 89168]
# 9                                          [Suite 052]
# 10                                          [Apt. 718]
# 11                                          [Apt. 718]
# 12                                                None
# 13                                         [Suite 281]
# 14                                          [Apt. 476]
# 15                                         [Suite 751]
# 16   [32266 Patterson Plain Suite 265 Alexandrashir...
# 17                                         [Suite 056]
# 18     [71707 Leblanc River New Annaborough, ID 83252]
# 19                                         [Suite 674]
# 20                                          [Apt. 406]
# 21                                                None
# 22                                                None
# 23   [60467 Deborah Vista Apt. 146 Port Karenfurt, ...
# 24   [970 Bethany Fords Suite 491 West Lisaside, NC...
# 25                                                None
# 26   [970 Bethany Fords Suite 491 West Lisaside, NC...
# 27                                          [Apt. 798]
# 28                                          [Apt. 392]
# 29                                         [Suite 298]
# ..                                                 ...
# 120                                               None
# 121                                               None
# 122                                               None
# 123                                               None
# 124                                               None
# 125                                               None
# 126                                               None
# 127                                               None
# 128                                               None
# 129                                               None
# 130                                               None
# 131                                               None
# 132                                               None
# 133                                               None
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                               None
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
#
# [150 rows x 4 columns]

# %%
from nltk.corpus import stopwords
from nameparser.parser import HumanName
from nltk.corpus import wordnet
stop = stopwords.words('english')

def extract_phone_numbers(string):
    r = re.compile(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})')
    phone_numbers = r.findall(string)
    return [re.sub(r'\D', '', number) for number in phone_numbers]

def extract_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)

#import pdb; pdb.set_trace()
person_list = []
person_names=person_list
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)

    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []
        

if __name__ == '__main__':
    train_data['numbers'] = train_data.Text.apply(lambda x: extract_phone_numbers(x))
    train_data['emails'] = train_data.Text.apply(lambda x: extract_email_addresses(x))
    train_data['names'] = train_data.Text.apply(lambda x: get_human_names(x))
    for person in person_list:
            person_split = person.split(" ")
            for name in person_split:
                if wordnet.synsets(name):
                    if(name in person):
                        person_names.remove(person)
                        break

# %%
train_data.head(10)
# Out:
#                                                 Text   Labels  \
# 0  Candidate economic character present money dau...  Address
# 1        Film range sound. People age Apt. 476 that.  Address
# 2  Back want myself class certain. Tree pretty ca...  Address
# 3  Bring guy 81627 Kimberly Squares Washingtonber...  Address
# 4  52013 Jason Vista Lake Kathleen, PA 89168 May ...  Address
# 5  Themselves early our bit. Institution peace sp...  Address
# 6  11792 Stevens Ferry Career respond front happe...  Address
# 7  Fine during five spring Apt. 174 page where la...  Address
# 8  Cup 52013 Jason Vista Lake Kathleen, PA 89168 ...  Address
# 9  Question Suite 052 as should sign face. Memory...  Address
#
#                                                PII  \
# 0                                         Apt. 026
# 1                                         Apt. 476
# 2                                        Suite 492
# 3  81627 Kimberly Squares Washingtonberg, RI 13540
# 4        52013 Jason Vista Lake Kathleen, PA 89168
# 5   4058 Gordon Fields South Charlestown, NJ 40537
# 6                              11792 Stevens Ferry
# 7                                         Apt. 174
# 8        52013 Jason Vista Lake Kathleen, PA 89168
# 9                                        Suite 052
#
#                                           Digit_data numbers emails names
# 0                                         [Apt. 026]      []     []  None
# 1                                         [Apt. 476]      []     []  None
# 2                                        [Suite 492]      []     []  None
# 3  [81627 Kimberly Squares Washingtonberg, RI 13540]      []     []  None
# 4        [52013 Jason Vista Lake Kathleen, PA 89168]      []     []  None
# 5   [4058 Gordon Fields South Charlestown, NJ 40537]      []     []  None
# 6                                               None      []     []  None
# 7                                         [Apt. 174]      []     []  None
# 8        [52013 Jason Vista Lake Kathleen, PA 89168]      []     []  None
# 9                                        [Suite 052]      []     []  None
